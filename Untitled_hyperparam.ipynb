# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
from MEM import MEM
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # random data tests

# %%
N = 15 
m = 10
X = np.random.rand(N, m)
y = (np.random.randint(0, 2, N) - 1/2)*2

# %%
clf = MEM(lmbda=0.1)
clf.fit(X, y)
accuracy_score(np.sign(clf.predict(X)), y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4db99f8b859a> in <module>
#       1 clf = MEM(lmbda=0.1)
#       2 clf.fit(X, y)
# ----> 3 accuracy_score(np.sign(clf.predict(X)), y)
#
# NameError: name 'accuracy_score' is not defined

# %%
from sklearn.datasets import make_blobs
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (14, 9)

# %%
N, m = 1000, 2
(X,y) =  make_blobs(n_samples=N,n_features=m,centers=2,cluster_std=2.05,random_state=40)
#we need to add 1 to X values (we can say its bias)
X1 = np.c_[np.ones((X.shape[0])),X]
y = (y - 0.5)*2

plt.scatter(X1[:,1],X1[:,2],marker='o',c=y)
plt.axis([-5,10,-12,-1])
plt.show()

# %%
clf = MEM(lmbda=0.1)
clf.fit(X, y)
accuracy_score(np.sign(clf.predict(X)), y)
# Out:
# 0.981

# %%
clf.predict_proba(X)
# Out:
# array([1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 6.45504098e-01, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 9.43377757e-01, 0.00000000e+00,
#        7.37774893e-01, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 5.86790623e-01, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 6.75447835e-02, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        9.02496621e-01, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 8.99568115e-01,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 4.15762652e-01,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.41360048e-01, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 4.84063705e-01, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.26446862e-01, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 7.40552608e-01,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 6.94472683e-01,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 2.33652665e-01, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        9.93997781e-01, 0.00000000e+00, 0.00000000e+00, 1.14132366e-01,
#        0.00000000e+00, 0.00000000e+00, 3.73268402e-01, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 7.42807483e-02, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        2.38739411e-02, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        6.72051999e-01, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 8.75983782e-01, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 2.62035085e-01, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.98608605e-01, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 3.25928316e-04, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 5.28451249e-01,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 2.18799386e-01, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        9.95254784e-01, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 7.98307880e-01,
#        1.00000000e+00, 3.97182828e-01, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        9.35463696e-01, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        9.20904883e-01, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 3.49299716e-01, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 8.92269065e-01, 1.00000000e+00,
#        0.00000000e+00, 3.44423418e-01, 1.50218338e-01, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 8.76245100e-01, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 2.87912524e-04, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        9.49697013e-01, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 2.85944007e-01,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 7.88524412e-01, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        3.59532237e-01, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 3.29203861e-01, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 7.78834341e-01, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 4.91361392e-01, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.58985439e-01,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 8.22051051e-02,
#        1.00000000e+00, 1.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 7.64358654e-01, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 9.02167897e-01, 1.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 8.22929465e-01, 1.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.00000000e+00,
#        1.00000000e+00, 1.00000000e+00, 6.74519984e-01, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 1.00000000e+00, 1.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.00000000e+00, 0.00000000e+00, 1.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 1.00000000e+00, 1.00000000e+00, 0.00000000e+00])

# %% [markdown]
# ## proba

# %% [markdown]
# # read datasets

# %%
import pandas as pd
import os
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# %% [markdown]
# it will be grate to add credit, promoters

# %%
dataset_names = [elem.split('.')[0] for elem in os.listdir('data')]
dataset_names
# Out:
# ['adult',
#  'adult',
#  'crx',
#  'hepatitis',
#  'house-votes-84',
#  'kr-vs-kp',
#  'promoters',
#  'synth']

# %%
dfs = []
for elem in os.listdir('data'):
    if elem.endswith('.data'):
        dfs.append(pd.read_csv('data/' + elem, header=None).replace('?', np.nan))
        dfs[-1].fillna(dfs[-1].mode().iloc[0], inplace=True)
        print(elem, ' ', len(dfs[-1]))
    
columns = list(dfs[0].columns)
columns = columns[1:] + [columns[0]]
ind = dataset_names.index('house-votes-84')
dfs[ind] = dfs[ind].reindex(columns=columns)

ind = dataset_names.index('adult')
dfs[ind] = dfs[ind].drop([2], axis=1)
# Out:
# adult.data   32561
# crx.data   690
# hepatitis.data   155
# house-votes-84.data   435
# kr-vs-kp.data   3196
# promoters.data   106
# synth.data   200

# %%
def extract_data(df, discrete=False):
    df = df.drop([df.columns[-1]], axis=1)
    if discrete:
        X = pd.get_dummies(df, columns=df.columns).values
    else:
        X = pd.get_dummies(df).values
    y = df[df.columns[-1]].values
    return X, y

# %%
lb = LabelEncoder()
data = []
for df in dfs:
    X, y = extract_data(df)
    y = (lb.fit_transform(y) - 0.5)*2
    data.append([X, y])

# %%
lb = LabelEncoder()
discrete_data = []
for df in dfs:
    X, y = extract_data(df, True)
    y = (lb.fit_transform(y) - 0.5)*2
    discrete_data.append([X, y])

# %% [markdown]
# # set up experiment

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
from tqdm import tqdm_notebook as tqdm

# %%
def process_clf(clf, num_iters, data=data):
    results = [[] for _ in range(len(data))]
    for i in tqdm(range(num_iters)):
        for j, (X, y) in enumerate(data):
            X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=i)
            clf.fit(X_train, y_train)
            results[j].append(1 - accuracy_score(y_test, clf.predict(X_test)))
    results = np.array(results)
    mean, var = results.mean(axis=1), results.var(axis=1)
    for name, vmean, vvar in zip(dataset_names, mean, var):
        print(f'{name:<15} mean: {vmean:<5},\t var: {vvar}')
    return

# %%
process_clf(LogisticRegression(solver='lbfgs', max_iter=300), 100)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# house-votes-84  mean: 0.038473282442748086,	 var: 0.0002260008158032744
# hepatitis       mean: 0.3427659574468086,	 var: 0.002932503395201449
# kr-vs-kp        mean: 0.03688216892596451,	 var: 3.948445167400454e-05
# adult           mean: 0.2018865799979527,	 var: 3.5711799985751346e-05

# %%
process_clf(MEM(), 3)
# Out:
# HBox(children=(IntProgress(value=0, max=3), HTML(value='')))
# house-votes-84  mean: 0.05343511450381677,	 var: 3.8847774993687364e-05
# hepatitis       mean: 0.30496453900709225,	 var: 0.0013077812987274283
# kr-vs-kp        mean: 0.029197080291970767,	 var: 2.6820894056381074e-05
# adult           mean: 0.30067901866448293,	 var: 0.002820511465470537

# %%
##hyperparametrs for MEM
lmbda_range = np.random.permutation([2**x for x in range(-10, 7)])
lmbda_score = np.zeros((lmbda_range.shape[0], len(data)))
print('Dataset\tlambda\taccuracy')
i=0
for x in lmbda_range:
    for j, (X, y) in (enumerate(data)):
        X_train,  X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True)
        mem = MEM(lmbda=x)
        X_train_lmbda, X_test_lmbda, y_train_lmbda, y_test_lmbda = train_test_split(X_train, y_train, 
                                                                                    test_size=0.3, shuffle=True)
        mem.fit(X_train_lmbda, y_train_lmbda)
        lmbda_score[i, j] = accuracy_score(y_test_lmbda, mem.predict(X_test_lmbda))
        print('\n',j, x, lmbda_score[i, j])
    i+=1
# Out:
# Dataset	lambda	accuracy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-ae087238d3e9> in <module>
#      10         X_train_lmbda, X_test_lmbda, y_train_lmbda, y_test_lmbda = train_test_split(X_train, y_train,
#      11                                                                                     test_size=0.3, shuffle=True)
# ---> 12         mem.fit(X_train_lmbda, y_train_lmbda)
#      13         lmbda_score[i, j] = accuracy_score(y_test_lmbda, mem.predict(X_test_lmbda))
#      14         print('\n',j, x, lmbda_score[i, j])
#
# ~\Desktop\ICT\Project\MEM.py in fit(self, X, y, lr, lr_decay, max_iter, min_diff)
#      30             grad = - np.sum(np.array([elem*m for elem, m in
#      31                                       zip(grad_multipliers*data_multipliers,
# ---> 32                                           nonzero_mask)]), axis=0) +\
#      33                                                     2*self.lmbda*self.alpha
#      34
#
# KeyboardInterrupt:

# %%
lmbda_opt= lmbda_range[np.amax(lmbda_score, axis=0)]

# %%
from sklearn.svm import SVC

# %%
process_clf(SVC(kernel='linear'), 3)
# Out:
# HBox(children=(IntProgress(value=0, max=3), HTML(value='')))
# house-votes-84  mean: 0.050890585241730256,	 var: 1.2949258331229122e-05
# hepatitis       mean: 0.3404255319148936,	 var: 0.000905387052965142
# kr-vs-kp        mean: 0.03058741744873128,	 var: 4.083541527503065e-05
# adult           mean: 0.20053229603848907,	 var: 1.6437298762501597e-05

# %%
##hyperparametrs for SVC
C = np.random.permutation([2**x for x in range(-5, 5)])
C_score = np.zeros((len(C), len(data)))
print('Dataset\t\tC\taccuracy')
i=0
for c in C:
    lmbda_score = np.zeros(len(lmbda_range))
    for j, (X, y) in (enumerate(data)):
        X_train,  X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True)
        svc = SVC(kernel='linear', C=c)
        X_train_C, X_test_C, y_train_C, y_test_C = train_test_split(X_train, y_train, test_size=0.3, shuffle=True)
        
        svc.fit(X_train_lmbda, y_train_lmbda)
        С_score[i, j] = accuracy_score(y_test_C, svc.predict(X_test_C))
        print('\n',j, x, С_score[i, j])
    i+=1

# %%
С_opt = lmbda_range[np.amax(С_score, axis=0)]

# %% [markdown]
# # DRC

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from DRC import DRC

# %%
clf = DRC()
clf.fit(X, y)
accuracy_score(clf.predict(X), y)
# Out:
# 1.0

# %%
process_clf(DRC(), 3, discrete_data)
# Out:
# HBox(children=(IntProgress(value=0, max=3), HTML(value='')))

# %%
clf = DRC()
num_iters = 3
results = [[] for _ in range(len(data[::2]))]
for i in tqdm(range(num_iters)):
    for j, (X, y) in enumerate(data[::2]):
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=i)
        clf.fit(X_train, y_train)
        results[j].append(1 - accuracy_score(y_test, clf.predict(X_test)))
results = np.array(results)
mean, var = results.mean(axis=1), results.var(axis=1)
for name, vmean, vvar in zip(dataset_names[::2], mean, var):
    print(f'{name:<15} mean: {vmean:<5},\t var: {vvar}')
# Out:
# HBox(children=(IntProgress(value=0, max=3), HTML(value='')))
# house-votes-84  mean: 0.050890585241730256,	 var: 1.2949258331229122e-05
# kr-vs-kp        mean: 0.06256517205422318,	 var: 8.69866834261008e-06

# %%
##hyperparameters for DRC
lmbda_range = np.random.permutation([2**x for x in range(-7, 6)])
lmbda_score_drc = np.zeros((lmbda_range.shape[0], len(discrete_data)))
print('Dataset\tlambda\taccuracy')
i=0
for x in lmbda_range:
    for j, (X, y) in (enumerate(discrete_data)):
        X_train,  X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True)
        drc = DRC(lmbda=x)
        X_train_lmbda, X_test_lmbda, y_train_lmbda, y_test_lmbda = train_test_split(X_train, y_train, 
                                                                                    test_size=0.3, shuffle=True)
        drc.fit(X_train_lmbda, y_train_lmbda)
        lmbda_score_drc[i, j] = accuracy_score(y_test_lmbda, drc.predict(X_test_lmbda))
        print('\n',j, x, lmbda_score_drc[i, j])
    i+=1
# Out:
# Dataset	lambda	accuracy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-628d02d76260> in <module>
#      10         X_train_lmbda, X_test_lmbda, y_train_lmbda, y_test_lmbda = train_test_split(X_train, y_train,
#      11                                                                                     test_size=0.3, shuffle=True)
# ---> 12         drc.fit(X_train_lmbda, y_train_lmbda)
#      13         lmbda_score_drc[i, j] = accuracy_score(y_test_lmbda, drc.predict(X_test_lmbda))
#      14         print('\n',j, x, lmbda_score_drc[i, j])
#
# ~\Desktop\ICT\Project\DRC.py in fit(self, X, y)
#      23                 return np.mean((W@z - C)**2) + self.lmbda*np.linalg.norm(z)**2
#      24
# ---> 25         self.z = minimize(loss_fun, np.ones(W.shape[1])).x
#      26
#      27     def predict(self, X):
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     595         return _minimize_cg(fun, x0, args, jac, callback, **options)
#     596     elif meth == 'bfgs':
# --> 597         return _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     598     elif meth == 'newton-cg':
#     599         return _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, **unknown_options)
#     981             alpha_k, fc, gc, old_fval, old_old_fval, gfkp1 = \
#     982                      _line_search_wolfe12(f, myfprime, xk, pk, gfk,
# --> 983                                           old_fval, old_old_fval, amin=1e-100, amax=1e100)
#     984         except _LineSearchError:
#     985             # Line search failed to find a better solution.
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#     801     ret = line_search_wolfe1(f, fprime, xk, pk, gfk,
#     802                              old_fval, old_old_fval,
# --> 803                              **kwargs)
#     804
#     805     if ret[0] is not None and extra_condition is not None:
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py in line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, args, c1, c2, amax, amin, xtol)
#      99     stp, fval, old_fval = scalar_search_wolfe1(
#     100             phi, derphi, old_fval, old_old_fval, derphi0,
# --> 101             c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#     102
#     103     return stp, fc[0], gc[0], fval, old_fval, gval[0]
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py in scalar_search_wolfe1(phi, derphi, phi0, old_phi0, derphi0, c1, c2, amax, amin, xtol)
#     173             alpha1 = stp
#     174             phi1 = phi(stp)
# --> 175             derphi1 = derphi(stp)
#     176         else:
#     177             break
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\linesearch.py in derphi(s)
#      88
#      89     def derphi(s):
# ---> 90         gval[0] = fprime(xk + s*pk, *newargs)
#      91         if gradient:
#      92             gc[0] += 1
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     291     def function_wrapper(*wrapper_args):
#     292         ncalls[0] += 1
# --> 293         return function(*(wrapper_args + args))
#     294
#     295     return ncalls, function_wrapper
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in approx_fprime(xk, f, epsilon, *args)
#     721
#     722     """
# --> 723     return _approx_fprime_helper(xk, f, epsilon, args=args)
#     724
#     725
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in _approx_fprime_helper(xk, f, epsilon, args, f0)
#     661         ei[k] = 1.0
#     662         d = epsilon * ei
# --> 663         grad[k] = (f(*((xk + d,) + args)) - f0) / d[k]
#     664         ei[k] = 0.0
#     665     return grad
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     291     def function_wrapper(*wrapper_args):
#     292         ncalls[0] += 1
# --> 293         return function(*(wrapper_args + args))
#     294
#     295     return ncalls, function_wrapper
#
# ~\Desktop\ICT\Project\DRC.py in loss_fun(z)
#      21
#      22         def loss_fun(z):
# ---> 23                 return np.mean((W@z - C)**2) + self.lmbda*np.linalg.norm(z)**2
#      24
#      25         self.z = minimize(loss_fun, np.ones(W.shape[1])).x
#
# KeyboardInterrupt:

# %%
lmbda_opt= lmbda_range[np.amax(lmbda_score, axis=0)]

# %% [markdown]
# # TAN

# %%
import pytan

# %%
process_clf(pytan.DiscreteBayesNetClassifier(), 3, discrete_data)

# %%
##hyperparameters for DRC
alpha_range = np.random.permutation([2**x for x in range(-6, 5)])
alpha_score = np.zeros((alpha_range.shape[0], len(discrete_data)))
print('Dataset\talpha\taccuracy')
i=0
for x in alpha_range:
    for j, (X, y) in (enumerate(discrete_data)):
        X_train,  X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True)
        tan = pytan.DiscreteBayesNetClassifier(alpha=x)
        X_train_lmbda, X_test_lmbda, y_train_lmbda, y_test_lmbda = train_test_split(X_train, y_train, 
                                                                                    test_size=0.3, shuffle=True)
        tan.fit(X_train_lmbda, y_train_lmbda)
        alpha_score[i, j] = accuracy_score(y_test_lmbda, tan.predict(X_test_lmbda))
        print('\n',j, x, alpha_score[i, j])
    i+=1
# Out:
# Dataset		accuracy

# %%
alpha_opt= lmbda_range[np.amax(alpha_score, axis=0)]
